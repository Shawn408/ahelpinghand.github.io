# %%
# IMPORT PACKAGES
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# opening the datasets
df = pd.read_csv("Homeless 2014.csv")
cf = pd.read_csv("Homeless 2013.csv")

# %%
# VIEW TOP 10 ROWS OF THE DATASET
df.head(10)
# Out:
#   State  Total Homeless  Sheltered Homeless  Unsheltered Homeless  \
# 0    AK            1784                1639                   145
# 1    AL            4561                3518                  1043
# 2    AR            2936                1503                  1433
# 3    AZ           10495                7926                  2569
# 4    CA          113952               42515                 71437
# 5    CO           10028                8083                  1945
# 6    CT            4450                3531                   919
# 7    DC            7748                7352                   396
# 8    DE             901                 864                    37
# 9    FL           41542               19851                 21691
#
#    Homeless Individuals  Sheltered Homeless Individuals  \
# 0                  1209                            1109
# 1                  3115                            2373
# 2                  2303                            1070
# ...

# %%
cf.head(10)
# Out:
#   State  Total Homeless  Sheltered Homeless  Unsheltered Homeless  \
# 0    AK            1946                1741                   205
# 1    AL            4689                3246                  1443
# 2    AR            3812                1664                  2148
# 3    AZ           10562                7431                  3131
# 4    CA          118552               45554                 72998
# 5    CO            9754                7591                  2163
# 6    CT            4448                3529                   919
# 7    DC            6865                6353                   512
# 8    DE             946                 936                    10
# 9    FL           47862               19670                 28192
#
#    Homeless Individuals  Sheltered Homeless Individuals  \
# 0                  1362                            1208
# 1                  3387                            2212
# 2                  3174                            1177
# ...

# %%
df.iloc[0:1, :6]
# Out:
#   State  Total Homeless  Sheltered Homeless  Unsheltered Homeless  \
# 0    AK            1784                1639                   145
#
#    Homeless Individuals  Sheltered Homeless Individuals
# 0                  1209                            1109

# %%
# shape shows (#rows, #columns)
df.shape
# Out:
# (54, 32)

# %%
y = df['Total Homeless']
x = cf['Total Homeless']

# %%
df.describe()
# Out:
#        Total Homeless  Sheltered Homeless  Unsheltered Homeless  \
# count       54.000000           54.000000             54.000000
# mean     10711.555556         7426.870370           3284.685185
# std      18964.804060        11875.348843          10057.626985
# min        448.000000           85.000000             20.000000
# 25%       2351.000000         1523.000000            371.250000
# 50%       5073.000000         3672.000000            925.500000
# 75%      11257.250000         8043.750000           2100.250000
# max     113952.000000        76487.000000          71437.000000
#
#        Homeless Individuals  Sheltered Homeless Individuals  \
# count             54.000000                       54.000000
# mean            6706.722222                     3873.111111
# std            13205.810131                     5211.708711
# min              332.000000                       37.000000
# 25%             1499.250000                     1079.750000
# ...

# %%
cf.describe()
# Out:
#        Total Homeless  Sheltered Homeless  Unsheltered Homeless  \
# count       54.000000           54.000000             54.000000
# mean     10958.666667         7309.222222           3649.444444
# std      19402.632303        11641.484600          10502.943802
# min        482.000000          119.000000             10.000000
# 25%       2475.500000         1625.000000            420.500000
# 50%       5670.500000         3674.500000           1233.000000
# 75%      11285.750000         7551.000000           2491.500000
# max     118552.000000        73273.000000          72998.000000
#
#        Homeless Individuals  Sheltered Homeless Individuals  \
# count             54.000000                       54.000000
# mean            6843.907407                     3761.611111
# std            13574.015801                     5185.618314
# min              296.000000                       35.000000
# 25%             1529.000000                     1078.250000
# ...

# %%
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn import metrics
# %matplotlib inline

# %%
X = df['Total Homeless'].values.reshape(-1,1)
y = cf['Total Homeless'].values.reshape(-1,1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
regressor = LinearRegression()  
regressor.fit(X_train, y_train) #training the algorithm
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
#To retrieve the intercept:
print(regressor.intercept_)

#For retrieving the slope:
print(regressor.coef_)
# Out:
# [191.89015897]
# [[0.99054778]]

# %%
y_pred = regressor.predict(X_test)

# %%
df = pd.DataFrame({'Actual': y_test.flatten(), 'Predicted': y_pred.flatten()})
df
# Out:
#     Actual      Predicted
# 0      953     941.734827
# 1     2819    2911.934358
# 2      482     635.655564
# 3     2403    2396.849513
# 4     1271    1535.072946
# 5     3812    3100.138436
# 6    12002   11752.573277
# 7     6544    5201.090273
# 8    29615   28417.549097
# 9     3145    3189.287736
# 10  118552  113066.790572

# %%
plt.title("Linear Regression Between Homeless Population")
plt.xlabel("2014")
plt.ylabel("2013")
plt.scatter(X_test, y_test,  color='black')
plt.plot(X_test, y_pred, color='red', linewidth=2)
plt.show()

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 869.0204189800223
# Mean Squared Error: 3090716.885053109
# Root Mean Squared Error: 1758.043482128104

# %%
df.iloc[0:1, 0:3]
# Out:
#    Actual   Predicted
# 0     953  941.734827
